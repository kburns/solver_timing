# %%
import numpy as np
import matplotlib.pyplot as plt
import shelve
from scipy import sparse
from scipy.sparse import linalg as spla
# %matplotlib notebook

# %%
matrices = shelve.open('matrices.dat', 'r')

def plot_matrix(M):
    plt.imshow(np.log10(np.abs(M.A)))

# %%
M = matrices['LHS'][5]

plt.figure()
plot_matrix(M)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="800">
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.

# %%
LU = spla.splu(M, permc_spec='NATURAL')
# Out:
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:295: SparseEfficiencyWarning: splu requires CSC matrix format
#   warn('splu requires CSC matrix format', SparseEfficiencyWarning)

# %%
plt.figure()
plot_matrix(LU.U)
# Out:
# <img src="data:image/png;base64,..." width="800">
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.

# %%
sparseqr.solv
# Out:
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sparseqr/sparseqr.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   Avals[0:nnz] = scipy_A.data
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sparseqr/sparseqr.py:158: ComplexWarning: Casting complex values to real discards the imaginary part
#   Adata[(j*lda):((j+1)*lda)] = numpy_A[:,j]
# array([ 0.,  0.,  0., ..., -0., -0., -0.])

# %%
M.dtype
# Out:
# dtype('complex128')

# %%
b = np.random.rand(3584) * 1j
