# %%
import numpy as np
import matplotlib.pyplot as plt
import problem

# %%
# %matplotlib notebook

# %%
solver, A = problem.build_LHS(128, 100, 'csr', entry_cutoff=1e-10)
# Out:
# 2018-12-15 15:51:54,713 pencil 0/1 INFO :: Building pencil matrix 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s

# %%
plt.figure()
plt.imshow(np.log10(np.abs(solver.pencils[0].L_exp.A)))
# Out:
# <img src="data:image/png;base64,..." width="800">
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10

# %%
solver.pencils[0].L.nnz
# Out:
# 22683

# %%
solver.pencils[0].M.nnz
# Out:
# 759

# %%
solver.pencils[0].M_exp.nnz
# Out:
# 23749
